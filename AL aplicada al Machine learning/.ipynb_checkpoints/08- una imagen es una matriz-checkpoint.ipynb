# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image #libreria para leer imagenes
from skimage import io # otra libreria para cargar imagenes y trabajar con imagenes

# %%
plt.style.use('classic') 

imagen = Image.open("..\\imagenes\\imagen_ejemplo_frida_bredesen.jpg")



image=io.imread("..\\imagenes\\imagen_ejemplo_frida_bredesen.jpg")/255.0 # imread lee las imagenes con los pixeles codificados como enteros 
# en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1

print("- Dimensiones de la imagen:")
print(image.shape)
plt.imshow(image,vmin=0,vmax=1)
#plt.imshow(imagen)
print(imagen.getbands)
# Out:
# - Dimensiones de la imagen:
# (3456, 3693, 3)
# <bound method Image.getbands of <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3693x3456 at 0x182DD51C100>>

# %%
### pasando a escala de grises
imagen_gr = imagen.convert('LA')
plt.imshow(imagen_gr)
print(imagen_gr)
print(imagen_gr.getbands)
# Out:
# <PIL.Image.Image image mode=LA size=3693x3456 at 0x182DF835100>
# <bound method Image.getbands of <PIL.Image.Image image mode=LA size=3693x3456 at 0x182DF835100>>

# %%
numpy.set_printoptions(threshold = False)

# %%
import sys
#import numpy

imagen_mat = np.array(list(imagen_gr.getdata(band=1)),float)

with np.printoptions(threshold=100):
    print(imagen_mat)

print(imagen_mat.shape)

# %%
print(imagen_mat.shape)
